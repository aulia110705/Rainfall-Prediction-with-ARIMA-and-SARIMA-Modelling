# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

file_path2 = '/content/data_train_winsor.xlsx'
data2 = pd.read_excel(file_path2)

data_hujan = data2['Curah_Hujan']
dates = pd.date_range(start='2020-01-01', periods=len(data_hujan), freq='D')

df_hujan = pd.Series(data_hujan.values, index=dates)
print(df_hujan.tail())

train = df_hujan

model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit()
print(model_fit.summary())
forecast = model_fit.forecast(steps=365)

forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')
forecast_series = pd.Series(forecast, index=forecast_dates)

plt.figure(figsize=(10,6))
# plt.plot(df_hujan, label='Data Curah Hujan 2020-2024')
plt.plot(forecast_series, label='Prediksi Curah Hujan 2025', color='green')
plt.legend()
plt.title('Prediksi Curah Hujan Tahun 2025 (SARIMA)')
plt.xlabel('Tanggal')
plt.ylabel('Curah Hujan (mm)')
plt.show()
# Out:
# 2024-12-27     0.0
# 2024-12-28    32.1
# 2024-12-29    22.9
# 2024-12-30    16.5
# 2024-12-31    26.5
# Freq: D, dtype: float64
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1827
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -7464.324
# Date:                            Thu, 12 Jun 2025   AIC                          14938.648
# Time:                                    13:31:19   BIC                          14966.164
# Sample:                                01-01-2020   HQIC                         14948.801
#                                      - 12-31-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0918      0.019      4.859      0.000       0.055       0.129
# ma.L1         -0.9299      0.008   -115.015      0.000      -0.946      -0.914
# ar.S.L12       0.0267      0.020      1.335      0.182      -0.013       0.066
# ma.S.L12      -0.9999      1.075     -0.930      0.352      -3.106       1.107
# sigma2       212.1841    227.520      0.933      0.351    -233.747     658.116
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):             19362.42
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.56   Skew:                             2.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# <ipython-input-7-1369026373>:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

file_path2 = '/content/data_train_winsor.xlsx'
data2 = pd.read_excel(file_path2)

data_hujan = data2['Curah_Hujan']
dates = pd.date_range(start='2020-01-01', periods=len(data_hujan), freq='D')

df_hujan = pd.Series(data_hujan.values, index=dates)
print(df_hujan.tail())

train = df_hujan

model = SARIMAX(train, order=(2, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit()
print(model_fit.summary())
forecast = model_fit.forecast(steps=365)

forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')
forecast_series = pd.Series(forecast, index=forecast_dates)

plt.figure(figsize=(10,6))
# plt.plot(df_hujan, label='Data Curah Hujan 2020-2024')
plt.plot(forecast_series, label='Prediksi Curah Hujan 2025', color='green')
plt.legend()
plt.title('Prediksi Curah Hujan Tahun 2025 (SARIMA)')
plt.xlabel('Tanggal')
plt.ylabel('Curah Hujan (mm)')
plt.show()
# Out:
# 2024-12-27     0.0
# 2024-12-28    32.1
# 2024-12-29    22.9
# 2024-12-30    16.5
# 2024-12-31    26.5
# Freq: D, dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1827
# Model:             SARIMAX(2, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -7454.567
# Date:                            Thu, 12 Jun 2025   AIC                          14921.134
# Time:                                    13:33:21   BIC                          14954.154
# Sample:                                01-01-2020   HQIC                         14933.318
#                                      - 12-31-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1003      0.019      5.251      0.000       0.063       0.138
# ar.L2          0.1113      0.020      5.446      0.000       0.071       0.151
# ma.L1         -0.9474      0.008   -117.284      0.000      -0.963      -0.932
# ar.S.L12       0.0347      0.020      1.698      0.089      -0.005       0.075
# ma.S.L12      -0.9999      0.855     -1.169      0.242      -2.676       0.676
# sigma2       209.8745    178.986      1.173      0.241    -140.931     560.680
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):             20139.62
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.56   Skew:                             2.97
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# <ipython-input-9-1193424424>:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

file_path2 = '/content/data_train_winsor.xlsx'
data2 = pd.read_excel(file_path2)

data_hujan = data2['Curah_Hujan']
dates = pd.date_range(start='2020-01-01', periods=len(data_hujan), freq='D')

df_hujan = pd.Series(data_hujan.values, index=dates)
print(df_hujan.tail())

train = df_hujan

model = SARIMAX(train, order=(3, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit()
print(model_fit.summary())
forecast = model_fit.forecast(steps=365)

forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')
forecast_series = pd.Series(forecast, index=forecast_dates)

plt.figure(figsize=(10,6))
# plt.plot(df_hujan, label='Data Curah Hujan 2020-2024')
plt.plot(forecast_series, label='Prediksi Curah Hujan 2025', color='green')
plt.legend()
plt.title('Prediksi Curah Hujan Tahun 2025 (SARIMA)')
plt.xlabel('Tanggal')
plt.ylabel('Curah Hujan (mm)')
plt.show()
# Out:
# 2024-12-27     0.0
# 2024-12-28    32.1
# 2024-12-29    22.9
# 2024-12-30    16.5
# 2024-12-31    26.5
# Freq: D, dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1827
# Model:             SARIMAX(3, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -7452.806
# Date:                            Thu, 12 Jun 2025   AIC                          14919.611
# Time:                                    13:33:57   BIC                          14958.134
# Sample:                                01-01-2020   HQIC                         14933.826
#                                      - 12-31-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1013      0.019      5.294      0.000       0.064       0.139
# ar.L2          0.1123      0.021      5.461      0.000       0.072       0.153
# ar.L3          0.0466      0.020      2.358      0.018       0.008       0.085
# ma.L1         -0.9530      0.009   -111.831      0.000      -0.970      -0.936
# ar.S.L12       0.0394      0.021      1.891      0.059      -0.001       0.080
# ma.S.L12      -0.9998      0.581     -1.720      0.085      -2.139       0.140
# sigma2       209.3985    121.221      1.727      0.084     -28.191     446.988
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             20235.35
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.57   Skew:                             2.97
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# <ipython-input-10-487210951>:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_dates = pd.date_range(start='2025-01-01', periods=12, freq='M')
